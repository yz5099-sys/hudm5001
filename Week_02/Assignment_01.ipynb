# %% [markdown]
# # Programming for Data Science — Assignment 01
# ## Assignment: Python Data Types, Variables & Expressions
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/cgpan/hudm5001/blob/main/Week_02/Assignment_01.ipynb)
#
# [**Chenguang Pan**](https://cpan.ai/), [**Youmi Lab**](https://youmilab.ai/)
# **Teachers College, Columbia University**
#
# This assignment accompanies the in-class notebook **`02_DataTypes_Variables_Expressions.ipynb`**. The best way to master programming is to **practice**. So roll up your sleeves and write code!
# Note: I refined wording in this notebook using Claude and am responsible for its accuracy. Please email me if you spot an error or a bug.

# %% [markdown]
# ---
# ### 📋 How this assignment works
#
# - **Run on Google Colab.** Open this notebook in Colab (the badge above), then *File ▸ Save a copy in Drive* to get your own editable copy.
# - **Scope.** Everything here uses **only** what we covered in Session 01. You will **not** need `for` loops, `if` statements, or custom functions (`def`) — and you're asked **not** to use them.
# - **Three parts:**
#   1. **Part A — Multiple Choice** (10 questions): test your understanding.
#   2. **Part B — Basic Exercises** (6 questions): short, focused drills, each centered on one data type or topic from class.
#   3. **Part C — Integrated Challenges** (4 questions): combine skills on real data-science / NLP / computer-vision / recommender tasks.
# - **Difficulty** is shown with stars, from ★☆☆☆☆ (easiest) to ★★★★★ (hardest). The **Skills** line tells you which tools from class each question exercises.
# - **Comment your code** and use **meaningful variable names** — the future you will thank you!
# - **AI Policy for this assignment:**
#     1. Attempt and check it yourself first.
#     2. Then refine with AI, if you want to.
#     3. Say what you used.
#     4. Own what you submit. You are responsible for every line you turn in and should be able to explain how it works if asked.
#
# **Total: 100 points** — Part A: 20 · Part B: 30 · Part C: 50.
# **Estimated time:**  2~3 hours for beginners.

# %% [markdown]
# ---
# ### ✍️ Before you start
# Fill in your name, then run the setup cell.

# %%
student_name = ""   # <-- type your name between the quotes
print("Submission by:", student_name)

# %%
# === SETUP — run me first! ===
# Pure-Python assignment — only the standard library, so it runs anywhere (including Colab).
import sys
print('Python', sys.version.split()[0])

# %% [markdown]
# ---
# ## Part A — Multiple Choice  *(2 points each, 20 total)*
#
# Read each question and decide on the best answer. You do **not** need to run any code for Part A — just reason it out. Record your answers (the letters) in the dictionary at the end of this part.

# %% [markdown]
# #### Question A1
# **Difficulty:** ★☆☆☆☆  **Skills:** `variable naming rules`
#
# Which of the following is a **valid** Python variable name?
#
# - **A.** `2nd_model`
# - **B.** `my-data`
# - **C.** `_hidden_score`
# - **D.** `class`
#
# *(Reminder: Python keywords such as `class`, `def`, and `return` cannot be used as variable names.)*

# %% [markdown]
# #### Question A2
# **Difficulty:** ★☆☆☆☆  **Skills:** `type()`, `str` vs `int`
#
# After running `age = "21"`, what does `type(age)` return?
#
# - **A.** `<class 'int'>`
# - **B.** `<class 'str'>`
# - **C.** `<class 'float'>`
# - **D.** `<class 'bool'>`

# %% [markdown]
# #### Question A3
# **Difficulty:** ★★☆☆☆  **Skills:** `str` concatenation, `print()` behavior
#
# What is printed by the code below? *(Just think — no need to run.)*
#
# ```python
# a = "3"
# b = "4"
# print(a + b)
# ```
#
# - **A.** `7`
# - **B.** `34`
# - **C.** `'34'`
# - **D.** `Error`

# %% [markdown]
# #### Question A4
# **Difficulty:** ★★☆☆☆  **Skills:** `str` indexing & slicing
#
# Given `s = "success"`, which expression returns the **last two** characters, `"ss"`?
#
# - **A.** `s[2]`
# - **B.** `s[-2:]`
# - **C.** `s[:2]`
# - **D.** `s[2:]`

# %% [markdown]
# #### Question A5
# **Difficulty:** ★★★☆☆  **Skills:** mutable vs immutable types
#
# Which line raises a `TypeError`?
#
# - **A.** `nums = [1, 2, 3]; nums[0] = 9`
# - **B.** `t = (1, 2, 3); t[0] = 9`
# - **C.** `d = {'a': 1}; d['b'] = 2`
# - **D.** `s = [1, 2]; s.append(3)`

# %% [markdown]
# #### Question A6
# **Difficulty:** ★★★☆☆  **Skills:** booleans, `and`/`or`/`not`, short-circuiting
#
# What does the code below print? *(Just think — no need to run. Tips: If Python detect the Flase in an `__ and __` expression, it will stop at False.)*
#
# ```python
# print(False and (1 / 0 > 0))
# ```
#
# - **A.** `False`
# - **B.** `0`
# - **C.** `ZeroDivisionError`
# - **D.** `True`

# %% [markdown]
# #### Question A7
# **Difficulty:** ★★☆☆☆  **Skills:** `set` uniqueness, `len()`
#
# What is the value of `len({"a", "b", "a", "c", "b"})`?
#
# - **A.** `5`
# - **B.** `3`
# - **C.** `2`
# - **D.** `1`

# %% [markdown]
# #### Question A8
# **Difficulty:** ★★★☆☆  **Skills:** type conversion, `int()` / `float()`
#
# Which expression raises a `ValueError`?
#
# - **A.** `int("42")`
# - **B.** `float("3.14")`
# - **C.** `int("3.8")`
# - **D.** `int(float("3.8"))`

# %% [markdown]
# #### Question A9
# **Difficulty:** ★★★☆☆  **Skills:** nested `dict` indexing
#
# What does the code below print?
#
# ```python
# profile = {"Jane": {"age": 22, "major": "Learning Analytics"}}
# print(profile["Jane"]["major"])
# ```
#
# - **A.** `Learning Analytics`
# - **B.** `{'age': 22, 'major': 'Learning Analytics'}`
# - **C.** `22`
# - **D.** `Error`

# %% [markdown]
# #### Question A10
# **Difficulty:** ★★☆☆☆  **Skills:** `range()`, `list()` conversion
#
# What is the value of `list(range(1, 10, 2))`?
#
# - **A.** `[1, 2, 3, 4, 5, 6, 7, 8, 9]`
# - **B.** `[1, 3, 5, 7, 9]`
# - **C.** `[1, 3, 5, 7, 9, 11]`
# - **D.** `[2, 4, 6, 8]`

# %% [markdown]
# #### ✅ Record your Part A answers
# Edit the dictionary below so each number maps to your chosen letter (for example, `1: "C"`). This reuses the **dictionary** skill from class!

# %%
my_mcq_answers = {
    1: "",   # your answer for Question A1
    2: "",   # your answer for Question A2
    3: "",   # your answer for Question A3
    4: "",   # your answer for Question A4
    5: "",   # your answer for Question A5
    6: "",   # your answer for Question A6
    7: "",   # your answer for Question A7
    8: "",   # your answer for Question A8
    9: "",   # your answer for Question A9
    10: "",   # your answer for Question A10
}
print(my_mcq_answers)

# %% [markdown]
# ---
# ## Part B — Basic Exercises  *(5 points each, 30 total)*
#
# Each exercise focuses on **one topic area** (one container or string skill) from class, using just a few closely related tools. Write your code in the empty cell under each prompt.

# %% [markdown]
# #### Exercise B1 — Compounding an investment
# **Difficulty:** ★☆☆☆☆  **Points:** 5
# **Skills:** `variables`, arithmetic (`*`, `**`), `round()`, f-string, `_` in numbers
#
# A client invests **\$1,000** in a fund that grows **5% every year** (a yearly multiplier of `1.05`) for **3 years**. The final value is `principal * (rate ** years)`.
#
# 1. Store the principal as `1_000` (use the underscore), the rate as `1.05`, and the number of years as `3`.
# 2. Compute the final value using `*` and `**`.
# 3. Round it to **2 decimals**.
# 4. Print a sentence with an **f-string**, e.g. `After 3 years, the investment is worth $1157.63`.

# %%
# Your code here

# %% [markdown]
# #### Exercise B2 — Dissecting a famous quote
# **Difficulty:** ★★☆☆☆  **Points:** 5
# **Skills:** `str` slicing, `.upper()`, `.replace()`, `len()`, f-string
#
# You are given the quote below. Using **string methods only** (no loops):
#
# ```python
# quote = "Data is the new oil"
# ```
#
# 1. Print the quote in **UPPERCASE**.
# 2. Print the **first 4** characters.
# 3. Print the **last 3** characters.
# 4. Print the **length** of the quote.
# 5. Print a version where `"oil"` is **replaced** by `"gold"`.
# 6. End with an f-string: `The quote has ___ characters.`

# %%
# Your code here

# %% [markdown]
# #### Exercise B3 — Daily step tracker
# **Difficulty:** ★★☆☆☆  **Points:** 5
# **Skills:** `list`, `.append()`, `.sort()`, indexing, `len()`
#
# You logged your daily step counts for four days:
#
# ```python
# steps = [8200, 10500, 6400, 12000]
# ```
#
# 1. **Append** a fifth day with `9300` steps.
# 2. **Sort** the list in ascending order and print it.
# 3. Print the **fewest** steps (the first element after sorting).
# 4. Print the **number of days** recorded.

# %%
# Your code here

# %% [markdown]
# #### Exercise B4 — A capitals lookup table
# **Difficulty:** ★★☆☆☆  **Points:** 5
# **Skills:** `dict`, key access, adding a key, `.keys()`
#
# Build a small lookup table of countries and their capitals.
#
# 1. Create a dictionary `capitals` with: France→Paris, Japan→Tokyo, Egypt→Cairo.
# 2. Print the capital of **Japan** by indexing with its key.
# 3. **Add** a new pair: Brazil→Brasilia.
# 4. Print all the **keys** of the dictionary.
# 5. Print the whole dictionary.

# %%
# Your code here

# %% [markdown]
# #### Exercise B5 — Comparing two survey responses
# **Difficulty:** ★★☆☆☆  **Points:** 5
# **Skills:** `set`, de-duplication, `.intersection()`, `.union()`, `in`
#
# Two students each listed the programming languages they know (with a repeat or two):
#
# ```python
# survey_a = {"Python", "R", "SQL", "Python"}
# survey_b = {"R", "SQL", "Julia"}
# ```
#
# 1. Print `survey_a` and notice the duplicate `"Python"` is gone.
# 2. Print the languages **both** students know (intersection).
# 3. Print **all** languages mentioned by either student (union).
# 4. Print whether `"Python"` is **in** `survey_a`.

# %%
# Your code here

# %% [markdown]
# #### Exercise B6 — Cleaning up a data record
# **Difficulty:** ★★☆☆☆  **Points:** 5
# **Skills:** `tuple`, unpacking, `int()` / `float()`, `type()`, f-string
#
# A raw data record arrives as a **tuple** where the numbers are stored as text:
#
# ```python
# record = ("Alice", "29", "1.68")   # (name, age, height in metres)
# ```
#
# 1. **Unpack** the tuple into `name`, `age_str`, `height_str`.
# 2. Convert the age to an `int` and the height to a `float`.
# 3. Print the **types** of your two converted values to confirm the conversion.
# 4. Print an f-string: `Alice is 29 years old and 1.68 m tall.`

# %%
# Your code here

# %% [markdown]
# ---
# ## Part C — Integrated Challenges  *(50 points total)*
#
# These bring several skills together on realistic tasks. Read the scenario, then complete the steps **using only Session-01 tools** (no `for`, no `if`, no `def`).

# %% [markdown]
# #### Exercise C1 — NLP — cleaning text and removing stop words
# **Difficulty:** ★★★★☆  **Points:** 12
# **Skills:** `.lower()`, `.replace()`, `.split()`, `len()`, arithmetic, f-string
#
# **Real-world setting: Natural Language Processing.** Before a computer can analyze text, we *pre-process* it: lowercase everything and drop very common "stop words" (like *the*, *is*, *and*) that carry little meaning. You'll do exactly that — **without any loops**.
#
# Here is a short product review:
#
# ```python
# review = "The model is fast and the model is accurate and reliable"
# ```
#
# Treat `"the"`, `"is"`, and `"and"` as stop words. Do the following:
#
# 1. **Lowercase** the review.
# 2. Split it into a list of words with `.split()` and count them with `len()` → call this `original_count`.
# 3. Remove the stop words. *Tip:* pad the text with a leading and trailing space, then use `.replace(" the ", " ")`, `.replace(" is ", " ")`, `.replace(" and ", " ")`. (Padding with spaces makes sure you only match whole words.)
# 4. Split the cleaned text and count the remaining words → `cleaned_count`.
# 5. Compute how many words were removed (`original_count - cleaned_count`).
# 6. Print a conclusion with an f-string: `Original: ___ words. Removed ___ stop words. Remaining: ___ words.`

# %%
# Your code here

# %% [markdown]
# #### Exercise C2 — Computer Vision — an image is just numbers
# **Difficulty:** ★★★★☆  **Points:** 12
# **Skills:** nested `list`, `[i][j]` indexing, slicing, arithmetic, `round()`, mutability, `len()`, f-string
#
# **Real-world setting: Computer Vision.** As we saw in class, a computer "sees" an image as a **grid of numbers** — each number is one pixel's brightness (0 = black, 255 = white). Here is a tiny 3×3 grayscale image stored as a list of rows.
#
# ```python
# image = [
#     [10, 200, 90],
#     [255, 128, 0],
#     [60, 75, 240],
# ]
# ```
#
# 1. Print the **top-left** pixel (row 0, column 0).
# 2. Print the entire **middle row**.
# 3. Print the **first two pixels** of the **last row** (use slicing).
# 4. Compute the **average brightness of the first row** using indexing and arithmetic (`(p0 + p1 + p2) / 3`), rounded to **1 decimal**. You can also try `sum()` function.
# 5. **Normalize** the center pixel to the 0–1 range by dividing it by `255`, rounded to **3 decimals**.
# 6. Pixels are editable — set the top-left pixel to `0` (darken that corner) and print the new first row.
# 7. Finish with an f-string describing the grid size, e.g. `This image is a 3 x 3 grid of numbers.`

# %%
# Your code here

# %% [markdown]
# #### Exercise C3 — Data Science — a mini gradebook
# **Difficulty:** ★★★★☆  **Points:** 13
# **Skills:** nested `dict`, `list`, indexing, `.keys()`, arithmetic, `round()`, `.sort(reverse=True)`, f-string
#
# **Real-world setting: Data Science.** A dictionary mapping names to lists of scores is a natural way to hold a small dataset — it's the seed of the *DataFrames* we'll meet later. Here is a class of three students, each with three quiz scores.
#
# ```python
# gradebook = {
#     "Maya": [88, 92, 79],
#     "Liam": [75, 85, 95],
#     "Noah": [100, 90, 80],
# }
# ```
#
# 1. Print all the **student names** (the keys).
# 2. Print **Liam's** list of scores.
# 3. Compute each student's **average** quiz score using indexing and arithmetic, each rounded to **1 decimal**. *(Three separate calculations — no loops needed.)*
# 4. Put the three averages into a **list**.
# 5. **Sort** that list from highest to lowest (`reverse=True`) and print it.
# 6. Print an f-string: `The highest quiz average in the class is ___.`

# %%
# Your code here

# %% [markdown]
# #### Exercise C4 — Recommender system — how alike are two users?
# **Difficulty:** ★★★★★  **Points:** 13
# **Skills:** `list`, `set()` de-dup, `.intersection()`, `.union()`, `len()`, `in`, arithmetic, `round()`, f-string
#
# **Real-world setting: Recommender Systems (the engines behind Netflix & Amazon).** A simple way to measure how similar two users' tastes are is the **Jaccard similarity**: the number of items they *both* like, divided by the number of items *either* likes. A score near `1` means very similar tastes; near `0` means very different. This capstone pulls together lists, sets, `len()`, arithmetic, and f-strings.
#
# Two users each gave a (messy, duplicate-containing) list of movies they liked:
#
# ```python
# user_a_likes = ["Inception", "Matrix", "Inception", "Interstellar", "Titanic"]
# user_b_likes = ["Matrix", "Titanic", "Avatar", "Matrix", "Up"]
# ```
#
# 1. Convert each list to a **set** to drop the duplicates; print both sets.
# 2. Find the movies they **both** like (intersection) and the **combined** catalog (union); print both.
# 3. Let `n_shared = len(...)` and `n_combined = len(...)`.
# 4. Compute the **Jaccard similarity** `n_shared / n_combined`, rounded to **2 decimals**.
# 5. Use a membership test to print whether User A likes `"Avatar"`.
# 6. Print a verdict with an f-string: `The two users share ___ of ___ movies. Similarity score = ___.`

# %%
# Your code here

# %% [markdown]
# ---
# ## 📤 Submission
#
# 1. Make sure every code cell **runs without errors** (*Runtime ▸ Run all* in Colab).
# 2. Double-check your Part A answer dictionary is filled in.
# 3. Save your notebook (*File ▸ Download ▸ .ipynb*, or share your Colab link) and submit it on **Canvas** as instructed.
